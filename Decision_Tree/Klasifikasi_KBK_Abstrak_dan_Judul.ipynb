# %%
import pandas as pd
import numpy as np
from tqdm import tqdm

tqdm.pandas()

# %%
df = pd.read_csv("data_kbk_mentah.csv")

# %%
df
# Out:
#         id                                              judul  \
# 0        1  <p>Pengembangan Sistem Pendukung Keputusan unt...
# 1        3  <p>HUBUNGAN EFIKASI DIRI DENGAN KESIAPAN KERJA...
# 2        4  <p>Alat Bantu Penyandang Tunanetra Berbasis De...
# 3        6  <p class="MsoNormal" style="margin-left:35.45p...
# 4        7  <p class="MsoNormal" align="center" style="tex...
# ...    ...                                                ...
# 2159  2199  <p align="center"><b>PENGARUH STATUS SOSIAL EK...
# 2160  2200  <p align="center">Pengaruh <i style="">Self Ef...
# 2161  2201  <p>Rancangan Alat Sistem Otomatis Serta Monito...
# 2162  2202  <p>Pengembangan Modul Mata Pelajaran Instrumen...
# 2163  2203  <p>Peningkatan Kompetensi Instalasi Penerangan...
#
#                                                 abstrak  \
# 0     <p>Sistem Pendukung Keputusan (SPK) merupakan ...
# 1     <p>Pandemi covid-19 yang melanda dunia, teruta...
# ...

# %%
df.columns
# Out:
# Index(['id', 'judul', 'abstrak', 'kbk'], dtype='object')

# %%
del df['id']

# %%
df
# Out:
#                                                   judul  \
# 0     <p>Pengembangan Sistem Pendukung Keputusan unt...
# 1     <p>HUBUNGAN EFIKASI DIRI DENGAN KESIAPAN KERJA...
# 2     <p>Alat Bantu Penyandang Tunanetra Berbasis De...
# 3     <p class="MsoNormal" style="margin-left:35.45p...
# 4     <p class="MsoNormal" align="center" style="tex...
# ...                                                 ...
# 2159  <p align="center"><b>PENGARUH STATUS SOSIAL EK...
# 2160  <p align="center">Pengaruh <i style="">Self Ef...
# 2161  <p>Rancangan Alat Sistem Otomatis Serta Monito...
# 2162  <p>Pengembangan Modul Mata Pelajaran Instrumen...
# 2163  <p>Peningkatan Kompetensi Instalasi Penerangan...
#
#                                                 abstrak  \
# 0     <p>Sistem Pendukung Keputusan (SPK) merupakan ...
# 1     <p>Pandemi covid-19 yang melanda dunia, teruta...
# 2     <p>Tujuan dilakukannya penelitian ini untuk me...
# 3     <p><span style="font-size:12.0pt;line-height:1...
# ...

# %%
df['abstrak'] = df['abstrak'].apply(lambda x: str(x))
df['judul'] = df['judul'].apply(lambda x: str(x))
df['kbk'] = df['kbk'].apply(lambda x: str(x))

# %%
df = df.dropna(axis='columns', inplace=True)

# %%
df
# Out:
#                                                   judul  \
# 0     <p>Pengembangan Sistem Pendukung Keputusan unt...
# 1     <p>HUBUNGAN EFIKASI DIRI DENGAN KESIAPAN KERJA...
# 2     <p>Alat Bantu Penyandang Tunanetra Berbasis De...
# 3     <p class="MsoNormal" style="margin-left:35.45p...
# 4     <p class="MsoNormal" align="center" style="tex...
# ...                                                 ...
# 2159  <p align="center"><b>PENGARUH STATUS SOSIAL EK...
# 2160  <p align="center">Pengaruh <i style="">Self Ef...
# 2161  <p>Rancangan Alat Sistem Otomatis Serta Monito...
# 2162  <p>Pengembangan Modul Mata Pelajaran Instrumen...
# 2163  <p>Peningkatan Kompetensi Instalasi Penerangan...
#
#                                                 abstrak  \
# 0     <p>Sistem Pendukung Keputusan (SPK) merupakan ...
# 1     <p>Pandemi covid-19 yang melanda dunia, teruta...
# 2     <p>Tujuan dilakukannya penelitian ini untuk me...
# 3     <p><span style="font-size:12.0pt;line-height:1...
# ...

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Text Cleaning

# %%
import re, string

# Cleaning
def cleaning(text):
  text = re.compile('<.*?>|&([a-z0-9]+|#[0-9]{1,6}|#x[0-9a-f]{1,6});').sub(' ', text)
  # Case folding
  text = (text.lower()) 
  # Trim text (Menghapus semua spasi dari teks kecuali spasi tunggal di antara kata-kata)
  text = text.strip()
  # Remove punctuations, special characters, and double whitespace
  text = re.compile('<.*?>').sub('', text) 
  text = re.compile('[%s]' % re.escape(string.punctuation)).sub(' ', text)
  text = re.sub('\s+', ' ', text)
  # Number removal
  text = re.sub(r'[0-9]', '', text) 
  text = re.sub(r'[^\w\s]', '', str(text).lower().strip())

  return text

# %%
df['abstrak'] = df['abstrak'].apply(lambda x: cleaning(x))
df['judul'] = df['judul'].apply(lambda x: cleaning(x))

# %%
df.replace('', np.nan)
# Out:
#                                                   judul  \
# 0     pengembangan sistem pendukung keputusan untuk ...
# 1     hubungan efikasi diri dengan kesiapan kerja lu...
# 2     alat bantu penyandang tunanetra berbasis detek...
# 3     analisis thermovisi penghantar akibat transmis...
# 4     pengembangan modul berbasis production based e...
# ...                                                 ...
# 2159  pengaruh status sosial ekonomi orang tua dan l...
# 2160  pengaruh self efficacy dan mastery experience ...
# 2161  rancangan alat sistem otomatis serta monitorin...
# 2162  pengembangan modul mata pelajaran instrumentas...
# 2163  peningkatan kompetensi instalasi penerangan li...
#
#                                                 abstrak  \
# 0     sistem pendukung keputusan spk merupakan suatu...
# 1     pandemi covid  yang melanda dunia terutama ind...
# 2     tujuan dilakukannya penelitian ini untuk memba...
# 3     gardu induk waru merupakan sub transmisi listr...
# ...

# %%
df[df['judul'].duplicated()]
# Out:
#                                                   judul  \
# 1243  pengembangan sistem pendukung keputusan untuk ...
# 1355  efektivitas penggunaan learning management sys...
# 1473                                                nan
# 1509                                                nan
#
#                                                 abstrak  \
# 1243  proses penentuan dosen pembimbing skripsi atau...
# 1355
# 1473                                                nan
# 1509  penelitian ini dilatarbelakangi karena adanya ...
#
#                                                     kbk
# 1243  Game Technology and Machine Learning Applications
# 1355  Pengembangan Aplikasi dan Media Pembelajaran T...
# 1473  Pengembangan Aplikasi dan Media Pembelajaran T...
# 1509       Strategi Pembelajaran Teknologi dan Kejuruan

# %%
# Hapus data duplikat
df.drop_duplicates(subset=['judul'], inplace=True)

# Apakah masih terdapat duplikasi pada kolom "judul"?
df[df['judul'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [judul, abstrak, kbk]
# Index: []

# %%
df[df['abstrak'].duplicated()]
# Out:
#                                                   judul abstrak  \
# 139   tingkat kesiapan calon guru millennial generat...     nan
# 143   pengaruh penggunaan aplikasi interaktif quizzi...     nan
# 156   implementasi metode naive bayes untuk klasifik...     nan
# 230   pengembangan media pembelajaran berbasis mobil...     nan
# 253   pengembangan modul digital pengemasan barang o...     nan
# ...                                                 ...     ...
# 1474  hubungan antara self efficacy dengan kemampuan...
# 1652
# 1760  pengembangan ar house solution untuk meningkat...
# 1836  pengembangan prototype aplikasi driver guna me...
# 2156  pengembangan media pembelajaran interaktif ber...
#
#                                                     kbk
# 139         Kurikulum Pendidikan Teknologi dan Kejuruan
# 143        Strategi Pembelajaran Teknologi dan Kejuruan
# 156   Game Technology and Machine Learning Applications
# 230   Pengembangan Aplikasi dan Media Pembelajaran T...
# ...

# %%
df.dropna(axis='columns', inplace=True)

# %%
# Hapus data duplikat
df.drop_duplicates(subset=['abstrak'], inplace=True)

# Apakah masih terdapat duplikasi pada kolom "abstrak"?
df[df['abstrak'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [judul, abstrak, kbk]
# Index: []

# %%
df['kbk'].value_counts()
# Out:
# Pengembangan Aplikasi dan Media Pembelajaran Teknologi dan Kejuruan              282
# Strategi Pembelajaran Teknologi dan Kejuruan                                     211
# Rekayasa pengetahuan dan ilmu data (Knowledge Engineering and Data Science)       99
# Kurikulum Pendidikan Teknologi dan Kejuruan                                       95
# Intelligent Power and Advanced energy System (IPAES)                              91
# Intelligent Power Electronics and Smart Grid (IPESG)                              88
# Ketenegakerjaan Teknologi dan Kejuruan                                            85
# Game Technology and Machine Learning Applications                                 80
# Evaluasi dan Pengelolaan Pendidikan Kejuruan                                      62
# Teknologi Digital Cerdas (Ubiquitous Computing Technique)                         62
# Telematics loT System and Devices                                                 58
# ...

# %%
df['judul']
# Out:
# 0       pengembangan sistem pendukung keputusan untuk ...
# 1       hubungan efikasi diri dengan kesiapan kerja lu...
# 2       alat bantu penyandang tunanetra berbasis detek...
# 3       analisis thermovisi penghantar akibat transmis...
# 4       pengembangan modul berbasis production based e...
#                               ...
# 2159    pengaruh status sosial ekonomi orang tua dan l...
# 2160    pengaruh self efficacy dan mastery experience ...
# 2161    rancangan alat sistem otomatis serta monitorin...
# 2162    pengembangan modul mata pelajaran instrumentas...
# 2163    peningkatan kompetensi instalasi penerangan li...
# Name: judul, Length: 1267, dtype: object

# %%
pd.set_option('display.max_rows', None)

# %%
df
# Out:
#                                                   judul  \
# 0     pengembangan sistem pendukung keputusan untuk ...
# 1     hubungan efikasi diri dengan kesiapan kerja lu...
# 2     alat bantu penyandang tunanetra berbasis detek...
# 3     analisis thermovisi penghantar akibat transmis...
# 4     pengembangan modul berbasis production based e...
# 5     pengaruh keterampilan mengajar asisten praktik...
# 6     pengembangan grafika app sistem tutor berbasis...
# 7     sistem monitoring dan kontrol berbasis suara m...
# 8     analisis hasil peramalan harga komoditas dagin...
# 9     hubungan antara keteladanan dosen dan kebermak...
# 10    penerapan modul pembelajaran teknik kerja beng...
# 11    perb andingan penerapan m odel pembelajaran au...
# 12    perbedaan penerapan model pembelajaran challen...
# 13    kendali fuzzy pid untuk penstabil tegangan out...
# 14    hubungan tingkat pemanfaatan internet s ebagai...
# 15    deteksi situs phishing menggunakan metode rand...
# ...

# %%
pd.reset_option("^display")

# %%
df
# Out:
#                                                   judul  \
# 0     pengembangan sistem pendukung keputusan untuk ...
# 1     hubungan efikasi diri dengan kesiapan kerja lu...
# 2     alat bantu penyandang tunanetra berbasis detek...
# 3     analisis thermovisi penghantar akibat transmis...
# 4     pengembangan modul berbasis production based e...
# ...                                                 ...
# 2159  pengaruh status sosial ekonomi orang tua dan l...
# 2160  pengaruh self efficacy dan mastery experience ...
# 2161  rancangan alat sistem otomatis serta monitorin...
# 2162  pengembangan modul mata pelajaran instrumentas...
# 2163  peningkatan kompetensi instalasi penerangan li...
#
#                                                 abstrak  \
# 0     sistem pendukung keputusan spk merupakan suatu...
# 1     pandemi covid  yang melanda dunia terutama ind...
# 2     tujuan dilakukannya penelitian ini untuk memba...
# 3     gardu induk waru merupakan sub transmisi listr...
# ...

# %%
# df.to_csv('data_clean.csv')

# %% [markdown]
# ## Tokenization

# %%
# !pip install Sastrawi --quiet

# %%
import nltk

# Tokenizing
nltk.download('punkt')
# Stopwords removal
nltk.download('stopwords')
# Lemmatizer
nltk.download('wordnet')
nltk.download('omw-1.4')

print('Completed')
# Out:
# Completed
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\tungg\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\tungg\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\tungg\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\tungg\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
from nltk.tokenize import word_tokenize

df['judul'] = df['judul'].apply(lambda x: word_tokenize(x))
df['judul']
# Out:
# 0       [pengembangan, sistem, pendukung, keputusan, u...
# 1       [hubungan, efikasi, diri, dengan, kesiapan, ke...
# 2       [alat, bantu, penyandang, tunanetra, berbasis,...
# 3       [analisis, thermovisi, penghantar, akibat, tra...
# 4       [pengembangan, modul, berbasis, production, ba...
#                               ...
# 2159    [pengaruh, status, sosial, ekonomi, orang, tua...
# 2160    [pengaruh, self, efficacy, dan, mastery, exper...
# 2161    [rancangan, alat, sistem, otomatis, serta, mon...
# 2162    [pengembangan, modul, mata, pelajaran, instrum...
# 2163    [peningkatan, kompetensi, instalasi, peneranga...
# Name: judul, Length: 1267, dtype: object

# %%
df['abstrak'] = df['abstrak'].apply(lambda x: word_tokenize(x))
df['abstrak']
# Out:
# 0       [sistem, pendukung, keputusan, spk, merupakan,...
# 1       [pandemi, covid, yang, melanda, dunia, terutam...
# 2       [tujuan, dilakukannya, penelitian, ini, untuk,...
# 3       [gardu, induk, waru, merupakan, sub, transmisi...
# 4       [mata, pelajaran, dasar, desain, grafis, merup...
#                               ...
# 2159    [penelitian, ini, dilaksanakan, untuk, mengeta...
# 2160    [aspek, aspek, yang, berpengaruh, dengan, kema...
# 2161    [perubahan, zaman, ke, era, otomatisasi, merup...
# 2162    [kementrian, pendidikan, kebudayaan, riset, da...
# 2163    [latar, belakang, dilakukannya, penelitian, ti...
# Name: abstrak, Length: 1267, dtype: object

# %% [markdown]
# ## Stopword Removal

# %%
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize
from itertools import chain

stop_words = set(chain(stopwords.words('indonesian'), stopwords.words('english')))

df['judul'].apply(lambda x: [w for w in x if not w in stop_words])
# Out:
# 0       [pengembangan, sistem, pendukung, keputusan, m...
# 1       [hubungan, efikasi, kesiapan, kerja, lulusan, ...
# 2       [alat, bantu, penyandang, tunanetra, berbasis,...
# 3       [analisis, thermovisi, penghantar, akibat, tra...
# 4       [pengembangan, modul, berbasis, production, ba...
#                               ...
# 2159    [pengaruh, status, sosial, ekonomi, orang, tua...
# 2160    [pengaruh, self, efficacy, mastery, experience...
# 2161    [rancangan, alat, sistem, otomatis, monitoring...
# 2162    [pengembangan, modul, mata, pelajaran, instrum...
# 2163    [peningkatan, kompetensi, instalasi, peneranga...
# Name: judul, Length: 1267, dtype: object

# %%
df['abstrak'].apply(lambda x: [w for w in x if not w in stop_words])
# Out:
# 0       [sistem, pendukung, keputusan, spk, sistem, me...
# 1       [pandemi, covid, melanda, dunia, indonesia, da...
# 2       [tujuan, dilakukannya, penelitian, membantu, p...
# 3       [gardu, induk, waru, sub, transmisi, listrik, ...
# 4       [mata, pelajaran, dasar, desain, grafis, mata,...
#                               ...
# 2159    [penelitian, dilaksanakan, pengaruh, status, s...
# 2160    [aspek, aspek, berpengaruh, kemantapan, pengam...
# 2161    [perubahan, zaman, era, otomatisasi, langkah, ...
# 2162    [kementrian, pendidikan, kebudayaan, riset, te...
# 2163    [latar, dilakukannya, penelitian, tindakan, ke...
# Name: abstrak, Length: 1267, dtype: object

# %% [markdown]
# ## Stemming

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

factory = StemmerFactory()
stemmer = factory.create_stemmer()
 
df['judul'] = df['judul'].progress_apply(lambda x: stemmer.stem(' '.join(x)).split(' '))
df['judul']
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1267/1267 [02:36<00:00,  8.09it/s]
# 0       [kembang, sistem, dukung, putus, untuk, tentu,...
# 1       [hubung, efikasi, diri, dengan, kesiap, kerja,...
# 2       [alat, bantu, sandang, tunanetra, bas, deteksi...
# 3       [analisis, thermovisi, hantar, akibat, transmi...
# 4       [kembang, modul, bas, production, based, educa...
#                               ...
# 2159    [pengaruh, status, sosial, ekonomi, orang, tua...
# 2160    [pengaruh, self, efficacy, dan, mastery, exper...
# 2161    [rancang, alat, sistem, otomatis, serta, monit...
# 2162    [kembang, modul, mata, ajar, instrumentasi, un...
# 2163    [tingkat, kompetensi, instalasi, terang, listr...
# Name: judul, Length: 1267, dtype: object

# %%
df['abstrak'] = df['abstrak'].progress_apply(lambda x: stemmer.stem(' '.join(x)).split(' '))
df['abstrak']
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1267/1267 [08:43<00:00,  2.42it/s]
# 0       [sistem, dukung, putus, spk, rupa, suatu, sist...
# 1       [pandemi, covid, yang, landa, dunia, utama, in...
# 2       [tuju, laku, teliti, ini, untuk, bantu, sandan...
# 3       [gardu, induk, waru, rupa, sub, transmisi, lis...
# 4       [mata, ajar, dasar, desain, grafis, rupa, mata...
#                               ...
# 2159    [teliti, ini, laksana, untuk, tahu, pengaruh, ...
# 2160    [aspek, aspek, yang, pengaruh, dengan, mantap,...
# 2161    [ubah, zaman, ke, era, otomatisasi, rupa, lang...
# 2162    [tri, didik, budaya, riset, dan, teknologi, ke...
# 2163    [latar, belakang, laku, teliti, tindak, kelas,...
# Name: abstrak, Length: 1267, dtype: object

# %% [markdown]
# ## Split Data

# %%
df['judul'] = df['judul'].apply(lambda x: ' '.join(x))
df['judul']
# Out:
# 0       kembang sistem dukung putus untuk tentu dosen ...
# 1       hubung efikasi diri dengan kesiap kerja lulus ...
# 2       alat bantu sandang tunanetra bas deteksi objek...
# 3       analisis thermovisi hantar akibat transmission...
# 4       kembang modul bas production based education a...
#                               ...
# 2159    pengaruh status sosial ekonomi orang tua dan l...
# 2160    pengaruh self efficacy dan mastery experience ...
# 2161    rancang alat sistem otomatis serta monitoring ...
# 2162    kembang modul mata ajar instrumentasi untuk du...
# 2163    tingkat kompetensi instalasi terang listrik de...
# Name: judul, Length: 1267, dtype: object

# %%
df['abstrak'] = df['abstrak'].apply(lambda x: ' '.join(x))
df['abstrak']
# Out:
# 0       sistem dukung putus spk rupa suatu sistem yang...
# 1       pandemi covid yang landa dunia utama indonesia...
# 2       tuju laku teliti ini untuk bantu sandang tunan...
# 3       gardu induk waru rupa sub transmisi listrik ya...
# 4       mata ajar dasar desain grafis rupa mata ajar y...
#                               ...
# 2159    teliti ini laksana untuk tahu pengaruh status ...
# 2160    aspek aspek yang pengaruh dengan mantap ambil ...
# 2161    ubah zaman ke era otomatisasi rupa langkah bes...
# 2162    tri didik budaya riset dan teknologi kemendikb...
# 2163    latar belakang laku teliti tindak kelas ini ka...
# Name: abstrak, Length: 1267, dtype: object

# %%
df['judtrak'] = [' '.join(i) for i in zip(df['judul'], df['abstrak'])]

# %%
df['judtrak']
# Out:
# 0       kembang sistem dukung putus untuk tentu dosen ...
# 1       hubung efikasi diri dengan kesiap kerja lulus ...
# 2       alat bantu sandang tunanetra bas deteksi objek...
# 3       analisis thermovisi hantar akibat transmission...
# 4       kembang modul bas production based education a...
#                               ...
# 2159    pengaruh status sosial ekonomi orang tua dan l...
# 2160    pengaruh self efficacy dan mastery experience ...
# 2161    rancang alat sistem otomatis serta monitoring ...
# 2162    kembang modul mata ajar instrumentasi untuk du...
# 2163    tingkat kompetensi instalasi terang listrik de...
# Name: judtrak, Length: 1267, dtype: object

# %%
# X = df['judul'].apply(lambda x: ' '.join(x))
# y = df['kbk']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df['judtrak'], df['kbk'], test_size=0.3, random_state=42)

# %%
X_train
# Out:
# 1931    rancang bangun sistem monitoring suhu dan ph a...
# 1834    kembang game kenal ekspresi wajah manusia untu...
# 1687    rancang bangun alat tekan darah bas smartphone...
# 1981    beda hasil ajar model ajar snowball throwing d...
# 2160    pengaruh self efficacy dan mastery experience ...
#                               ...
# 1940    alat bantu masak nasi goreng untuk sandang tun...
# 1991    kembang trainer synchronous buck converter gun...
# 2026    hubung alam ajar kewirausahaan dengan mampu pr...
# 1754    smart plug bas iot mengguanakan mikrokontroler...
# 2022    analisis kualitas isolasi gas sf pada putus te...
# Name: judtrak, Length: 886, dtype: object

# %%
# df.to_csv('data_clean.csv')

# %% [markdown]
# # Pembobotan

# %% [markdown]
# ## TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer()

X_train_vectors_tfidf = tfidf_vectorizer.fit_transform(X_train) 
X_test_vectors_tfidf = tfidf_vectorizer.transform(X_test)

print('Train size: ', X_train_vectors_tfidf.shape)
print('Test size: ', X_test_vectors_tfidf.shape)
# Out:
# Train size:  (886, 7998)
# Test size:  (381, 7998)

# %% [markdown]
# # Resampling

# %% [markdown]
# ## SMOTE

# %%
y_train.value_counts()
# Out:
# Pengembangan Aplikasi dan Media Pembelajaran Teknologi dan Kejuruan              190
# Strategi Pembelajaran Teknologi dan Kejuruan                                     147
# Intelligent Power and Advanced energy System (IPAES)                              66
# Rekayasa pengetahuan dan ilmu data (Knowledge Engineering and Data Science)       66
# Kurikulum Pendidikan Teknologi dan Kejuruan                                       65
# Intelligent Power Electronics and Smart Grid (IPESG)                              61
# Game Technology and Machine Learning Applications                                 61
# Ketenegakerjaan Teknologi dan Kejuruan                                            56
# Evaluasi dan Pengelolaan Pendidikan Kejuruan                                      52
# Teknologi Digital Cerdas (Ubiquitous Computing Technique)                         44
# Telematics loT System and Devices                                                 40
# ...

# %%
from imblearn.over_sampling import SMOTE

X_train_resampled, y_train_resampled = SMOTE(random_state=42).fit_resample(X_train_vectors_tfidf, y_train)

# %%
y_train_resampled.value_counts()
# Out:
# Biomedic and Intelligent Assistive Technology (TAT)                              190
# Teknologi Digital Cerdas (Ubiquitous Computing Technique)                        190
# Strategi Pembelajaran Teknologi dan Kejuruan                                     190
# Ketenegakerjaan Teknologi dan Kejuruan                                           190
# Pengembangan Aplikasi dan Media Pembelajaran Teknologi dan Kejuruan              190
# Kurikulum Pendidikan Teknologi dan Kejuruan                                      190
# Evaluasi dan Pengelolaan Pendidikan Kejuruan                                     190
# Intelligent Power Electronics and Smart Grid (IPESG)                             190
# Intelligent Power and Advanced energy System (IPAES)                             190
# Sistem Dinamis, Kendali, dan Robotika (Dynamic Systems, Control and Robotics)    190
# Rekayasa pengetahuan dan ilmu data (Knowledge Engineering and Data Science)      190
# ...

# %% [markdown]
# # Training Model

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

dtc = DecisionTreeClassifier()
dtc.fit(X_train_resampled, y_train_resampled)

y_pred = dtc.predict(X_test_vectors_tfidf)

print('Accuracy score : ', accuracy_score(y_test, y_pred))
print('Precision score : ', precision_score(y_test, y_pred, average='weighted'))
print('Recall score : ', recall_score(y_test, y_pred, average='weighted'))
print('F1 score : ', f1_score(y_test, y_pred, average='weighted'))
# Out:
# Accuracy score :  0.49606299212598426
# Precision score :  0.5601167438188565
# Recall score :  0.49606299212598426
# F1 score :  0.5162990760877356

# %% [markdown]
# ## Evaluation

# %%
from sklearn.metrics import ConfusionMatrixDisplay
from matplotlib import pyplot as plt

ConfusionMatrixDisplay.from_predictions(y_test, y_pred, cmap='Blues')
plt.show()

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#                                                                                precision    recall  f1-score   support
#
#                           Biomedic and Intelligent Assistive Technology (TAT)       0.14      0.22      0.17         9
#                                  Evaluasi dan Pengelolaan Pendidikan Kejuruan       0.17      0.50      0.25        10
#                             Game Technology and Machine Learning Applications       0.24      0.47      0.32        19
#                          Intelligent Power Electronics and Smart Grid (IPESG)       0.52      0.48      0.50        27
#                          Intelligent Power and Advanced energy System (IPAES)       0.56      0.56      0.56        25
#                                        Ketenegakerjaan Teknologi dan Kejuruan       0.55      0.38      0.45        29
#                                   Kurikulum Pendidikan Teknologi dan Kejuruan       0.39      0.30      0.34        30
# ...

# %% [markdown]
# ## Export Model

# %%
# from joblib import dump

# dump(dtc, filename="dtc-model.joblib")
# Out:
# ['dtc-model.joblib']

# %%
title_input = input("Masukkan Judul + Abstraksi:\n")

hasil = dtc.predict(tfidf_vectorizer.transform([title_input]))

print(f"Judult + Abstraksi: {title_input}")
print("Klasifikasi topik: " + "".join(hasil))
# Out:
# Masukkan Abstraksi:
# ...

# %%
title_input = input("Masukkan Abstraksi:\n")

hasil = dtc.predict(tfidf_vectorizer.transform([title_input]))

print(f"Abstraksi: {title_input}")
print("Klasifikasi topik: " + "".join(hasil))
# Out:
# Masukkan Abstraksi:
# ...

# %%
# Demo menggunakan model yang telah disimpan
# from sklearn.feature_extraction.text import TfidfVectorizer
# from joblib import load
# title_input = input("Masukkan judul berita:\n")
# title_input = tfidf_vectorizer.transform([title_input])
# loaded_model = load('dtc-model.joblib')

# y_pred = loaded_model.predict(title_input)
# print(f"Judul Berita: {title_input}")
# print("Klasifikasi topik: " + "".join(y_pred))

# %% [markdown]
# **Contoh Input :**
#
# kembang sistem dukung putus untuk tentu dosen bimbing guna algoritma simple additive weighting saw pada sistem informasi skripsi dan tugas akhir di jurus teknik elektro universitas negeri malang sistem dukung putus spk rupa suatu sistem yang milik mampu pecah masalah yang guna untuk bantu ambil putus dalam situasi semi struktur dan situasi yang tidak struktur di jurus teknik elektro universitas negeri malang tentu dosen bimbing skripsi atau tugas akhir tentu oleh kbk dan koorprodi dasar hasil wawancara dengan salah satu dosen kbk ada beberapa kriteria tentu dosen bimbing yaitu jabat golong didik dosen sesuai judul dengan bidang ahli dosen jumlah mahasiswa bimbing dosen sebut sistem informasi skripsi dan tugas akhir dapat tangan daftar judul laku catat bimbing dan daftar seminar atau sidang teliti ini tuju untuk kembang sistem dukung putus guna sedia informasi dan rekomendasi dosen bimbing yang sesuai dasar pada beberapa kriteria yang telah tentu agar mudah kbk dalam laku pilih dosen bimbing skripsi dan tugas akhir sehingga tidak jadi gelembung jumlah mahasiswa bimbing pada salah satu dosen bimbing spk pada sisinta ini kembang guna model waterfall yang diri dari empat langkah yaitu analyze design code test algoritma yang terap pada spk ini adalah simple additive weighting saw untuk beri rekomendasi dosen bimbing yang sesuai dengan judul yang aju dengan kembang spk harap dapat beri informasi dan rekomendasi sehingga bantu dan mudah kbk dalam tentu dosen bimbing skripsi atau tugas akhir dari tiap judul yang masuk pada sistem informasi skripsi dan tugas akhir

# %% [markdown]
# klasifikasi kelompok bidang keahlian (kbk) berdasarkan judul dan abstrak skripsi menggunakan algoritma decision tree sisinta um adalah sistem informasi berbasis website bertujuan untuk menampilkan data yang berkaitan dengan skripsi dan tugas akhir pada jurusan teknik elektro fakultas teknik universitas negeri malang penggunaan sistem informasi sisinta memiliki potensi jika dikembangkan dengan mengklasifikasikan judul dan abstrak berdasarkan tema penelitiannya tujuan penelitian ini adalah untuk menerapkan dan menguji performa algoritma decision tree classifier dalam mengklasifikasi judul skripsi dan tugas akhir berdasarkan tema penelitian dalam kbk di jurusan teknik elektro ft um decision tree classifier adalah algoritma supervised learning non parametrik yang digunakan untuk klasifikasi dan regresi decision tree memiliki hierarki struktur pohon yang terdiri dari root node, branches internal nodes dan leaf nodes dengan menggunakan metode decision tree classifier dalam implementasinya diharapkan dapat memprediksi jenis kelompok bidang keahlian yang sesuai data yang digunakan dalam penelitian sistem klasifikasi ini didapatkan dari database sisinta te um berupa judul abstrak dan kbk yang terkait dengan tema penelitian pada skripsi dan tugas akhir tersebut
